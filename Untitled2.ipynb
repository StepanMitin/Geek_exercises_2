# %% [markdown]
# <a href="https://colab.research.google.com/github/StepanMitin/Geek_exercises_2/blob/master/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
#data = pd.read_excel('finel_table.xlsx')
data = pd.read_excel(r'/content/finel_table.xlsx')

# print(data)

grouped_data = data.groupby('Тип точки').agg({'Выручка':'sum', 'Число покупок': 'sum'}).reset_index()
grouped_data['Средений чек'] = grouped_data['Выручка']/grouped_data['Число покупок']
display(grouped_data)
# Out:
#              Тип точки  Выручка  Число покупок  Средений чек
# 0  Вендинговый автомат   202679           3949     51.324133
# 1                 Кафе   193960           1768    109.705882
# 2                Киоск   221969           2666     83.259190
